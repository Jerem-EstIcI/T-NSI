# %%
def occurrences(caractere,chaine):
    """
    >>> occurrences('e', "sciences") 
    2 
    >>> occurrences('i',"mississippi") 
    4 
    >>> occurrences('a',"mississippi") 
    0
    """
    nb=0
    for lettre in chaine:
        if lettre==caractere:
            nb+=1
    return nb

# %%
occurrences('e', "sciences")
# Out:
# 2

# %%
occurrences('i',"mississippi")
# Out:
# 4

# %%
occurrences('a',"mississippi")
# Out:
# 0

# %%
def rendu_glouton(a_rendre, rang): 
    """
    >>> rendu_glouton(67, 0) 
    [50, 10, 5, 2] 
    >>> rendu_glouton(291, 0) 
    [100, 100, 50, 20, 20, 1] 
    >>> rendu_glouton(291,1) 
    # si on ne dispose pas de billets de 100 [50, 50, 50, 50, 50, 20, 20, 1]
    """
    valeurs = [100, 50, 20, 10, 5, 2, 1]
    if a_rendre == 0: 
        return [] 
    v = valeurs[rang] 
    if v <= a_rendre: 
        return [v] + rendu_glouton(a_rendre- v, rang) 
    else: 
        return rendu_glouton(a_rendre, rang+1)

# %%
rendu_glouton(67, 0)
# Out:
# [50, 10, 5, 2]

# %%
rendu_glouton(291, 0)
# Out:
# [100, 100, 50, 20, 20, 1]

# %%
rendu_glouton(291,1)
# Out:
# [50, 50, 50, 50, 50, 20, 20, 1]
