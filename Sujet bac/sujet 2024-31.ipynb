# %%
import tutor
def multiplication(n1,n2):
    """
    >>> multiplication(3, 5) 
    15 
    >>> multiplication(-4,-8) 
    32 
    >>> multiplication(-2, 6)
    -12 
    >>> multiplication(-2, 0) 
    0
    """
    somme=0
    tempn1=n1
    tempn2=n2
    
    if n1==0 or n2==0:
        return 0
    
    elif n1>0 and n2>0:
        for nb in range(tempn2):
            somme+=n1
        return somme
    
    elif n1<0 or n2<0:
        if n1<0:
            tempn1=-tempn1
        if n2<0:
            tempn2=-n2
            
        for nb in range(tempn2):
            somme+=tempn1
            
        if n1>0 or n2>0:
            return -somme
        else:
            return somme

# %%
multiplication(3, 5)
# Out:
# 15

# %%
multiplication(-4,-8)
# Out:
# 32

# %%
multiplication(-2, 6)
# Out:
# -12

# %%
multiplication(-2, 0)
# Out:
# 0

# %%
def dichotomie(tab, x): 
    """ tab : tableau d'entiers trié dans l'ordre croissant 
    x : nombre entier La fonction renvoie True si tab contient x et False sinon 
    >>> dichotomie([15, 16, 18, 19, 23, 24, 28, 29, 31, 33],28) 
    True 
    >>> dichotomie([15, 16, 18, 19, 23, 24, 28, 29, 31, 33],27) 
    False
    """ 
    debut = 0 
    fin = len(tab)- 1 
    while debut <= fin: 
        m = (debut+fin)//2 
        if x == tab[m]: 
            return True 
        if x > tab[m]: 
            debut = m + 1 
        else: 
            fin = m-1
    return False

# %%
dichotomie([15, 16, 18, 19, 23, 24, 28, 29, 31, 33],28)
# Out:
# True

# %%
dichotomie([15, 16, 18, 19, 23, 24, 28, 29, 31, 33],27)
# Out:
# False
