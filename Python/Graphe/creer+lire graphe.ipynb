# %%
from random import random,randint

def cree_graphe(nom,ordre,densite):
    with open(nom,'w') as f:
        f.write(str(ordre)+'\n')
        m=int(ordre*(ordre-1)//2*densite)
        dejavu=[[False for i in range(ordre)] for j in range(ordre)]
        couples=set()
        while m>0:
            s1,s2=randint(0,ordre-1),randint(0,ordre-1)
            if s1!=s2 and not dejavu[s1][s2]:
                poids=randint(5,30)
                f.write(f"{s1} {s2} {poids}\n")
                dejavu[s1][s2]=True
                dejavu[s2][s1]=True
                m-=1
            
def lire_graphe(nom):
    with open(nom) as f:
        lignes=f.readlines()
        ordre=(int(lignes[0].strip()))
        res=[[]for k in range(ordre)]
        for ligne in lignes[1:]:
            u=ligne.strip().split(' ')
            s1,s2,w=int(u[0]),int(u[1]),int(u[2])
            print(s1,s2,w);res[s1].append([s2,w])
            print(s2,s1,w);res[s2].append([s1,w])
        return res
            
        
        
def Dijkstra(G,w,s):
    
    pass

# %%
cree_graphe('test',10,0.3)

# %%
lire_graphe('test')
# Out:
# 0 8 18
# 8 0 18
# 3 8 22
# 8 3 22
# 0 9 24
# 9 0 24
# 9 2 20
# 2 9 20
# 0 5 28
# 5 0 28
# 7 6 15
# 6 7 15
# 5 8 30
# 8 5 30
# 4 5 10
# 5 4 10
# 6 8 10
# 8 6 10
# 5 7 10
# 7 5 10
# 0 1 20
# 1 0 20
# 7 3 18
# 3 7 18
# 8 4 7
# 4 8 7
# [[[8, 18], [9, 24], [5, 28], [1, 20]], [[0, 20]], [[9, 20]], [[8, 22], [7, 18]], [[5, 10], [8, 7]], [[0, 28], [8, 30], [4, 10], [7, 10]], [[7, 15], [8, 10]], [[6, 15], [5, 10], [3, 18]], [[0, 18], [3, 22], [5, 30], [6, 10], [4, 7]], [[0, 24], [2, 20]]]

# %%
import basthon
basthon.download('test')
