# %% [markdown]
# Récursion
# =========
#
# Une **fonction récursive** est une fonction qui s'appelle elle-même.
#
# Une **structure récursive** est une structure définie à partir d'elle-même.
#
# Ce notebook contient des exercices variés autour de la notion de récursivité.

# %% [markdown]
# **Ex1** Compléter la fonction `puissance(x,n)`, qui calcule $x^n$.

# %%
def puissance(x,n):
    """
    cette fonction calcule récursivement x**n avec l'égalité x**n=x*x**(n-1)
    et le cas de base x**0=1
    >>> puissance(2,10)
    1024
    >>> puissance(10,0)
    1
    """
    if n==0:
        return 1
    else:
        return x*puissance(x,n-1)

import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=2)

# %% [markdown]
# **Ex2** Recherche dans une liste tête-queue
#
# On s'intéresse à une structure récursive, la structure de liste "tête-queue" : on considère qu'une liste est soit vide, soit composée d'une tête (le premier élément), et d'une queue qui est une liste éventuellement vide.
#
# P.ex pour `l=[2,3,12]` la tête est `2` et la queue est `[3,12]`, obtenues respectivement par `l[0]` et `l[1]`.

# %%
l=[1,2,3]

# %%
l[0]
# Out:
# 1

# %%
l[1:]
# Out:
# [2, 3]

# %% [markdown]
# Ecrire la fonction `somme(l)` qui renvoie la somme des éléments de la liste `l`.

# %%
def somme(l):
    """
    >>> somme([])
    0
    >>> somme([2,3,12])
    17
    """
    if l==[]:
        return 0
    else:
        return l[0] + somme(l[1:])

import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=4)

# %% [markdown]
# **Ex3** Exponentiation rapide
#
# La fonction `qexp(x,n)` calcule $x^n$ avec $n\geqslant0$ en utilisant les propriétés suivantes :
# * si $n=2k$ est pair, alors $x^n=\left(x^2\right)^k$
# * si $n=2k+1$ est impair, alors $x^n=x\times x^{n-1}$
#
# Corriger l'implémentation incorrecte proposée ci-dessous.

# %%
def qexp(x,n):
    print(x,n)
    if n==0:
        return 1
    if n%2==0:
        return qexp(x**2,n//2)
    else:
        return x*qexp(x,n-1)
    
qexp(2,42)
# Out:
# 2 42
# 4 21
# 4 20
# 16 10
# 256 5
# 256 4
# 65536 2
# 4294967296 1
# 4294967296 0
# 4398046511104

# %% [markdown]
# **Ex4** En utilisant `tutor`, donner la pile des appels successifs de la fonction `binaire` définie ci-dessous, avec le cas d'usage `binaire(42)` ;
#
# sur chaque ligne on écrira la fonction avec la valeur du paramètre, et à côté la valeur renvoyée.

# %%
import tutor

def binaire(n):
    if n==0:
        return '0'
    elif n==1:
        return '1'
    else:
        debut=binaire(n//2)
        if n%2==0:
            fin='0'
        else:
            fin='1'
        return debut+fin
    
binaire(42)

tutor.tutor()
# Out:
# <iframe id="basthon-pythontutor-iframe-0" style="width: 100%; height: 400px;" frameborder="0" src="data:text/html;charset=utf-8,%3C%21DOCTYPE%20html%3E%0A%3Chtml%3E%0A%20%20%3Chead%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//notebook.basthon.fr/assets/0.60.2/python3/modules/extern/pytutor-main.min.css%22/%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//notebook.basthon.fr/assets/0.60.2/python3/modules/extern/pytutor-main.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20let%20sent_height%3B%0A%20%20%20%20%20%20%24%28document%29.ready%28function%28%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20//%20managing%20iframe%20resize%0A%20%20%20%20%20%20%20%20%20%20const%20send%20%3D%20%28%29%20%3D%3E%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20const%20new_height%20%3D%20document.body.offsetHeight%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20if%20%28sent_height%20%3D%3D%3D%20new_height%29%20return%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20sent_height%20%3D%20new_height%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20window.parent.postMessage%28%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20type%3A%20%22pytutor-iframe-resize%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20target%3A%20%22basthon-pythontutor-iframe-0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20sent_height%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%2C%20%27%2A%27%29%3B%0A%20%20%20%20%20%20%20%20%20%20%7D%3B%0A%20%20%20%20%20%20%20%20%20%20const%20o%20%3D%20new%20ResizeObserver%28send%29%3B%0A%20%20%20%20%20%20%20%20%20%20o.observe%28document.body%29%3B%0A%0A%20%20%20%20%20%20%20%20%20%20const%20t%20%3D%20%7B%22code%22%3A%20%22def%20binaire%28n%29%3A%5Cn%20%20%20%20if%20n%3D%3D0%3A%5Cn%20%20%20%20%20%20%20%20return%20%270%27%5Cn%20%20%20%20elif%20n%3D%3D1%3A%5Cn%20%20%20%20%20%20%20%20return%20%271%27%5Cn%20%20%20%20else%3A%5Cn%20%20%20%20%20%20%20%20debut%3Dbinaire%28n//2%29%5Cn%20%20%20%20%20%20%20%20if%20n%252%3D%3D0%3A%5Cn%20%20%20%20%20%20%20%20%20%20%20%20fin%3D%270%27%5Cn%20%20%20%20%20%20%20%20else%3A%5Cn%20%20%20%20%20%20%20%20%20%20%20%20fin%3D%271%27%5Cn%20%20%20%20%20%20%20%20return%20debut%2Bfin%5Cn%20%20%20%20%5Cnbinaire%2842%29%22%2C%20%22trace%22%3A%20%5B%7B%22line%22%3A%201%2C%20%22event%22%3A%20%22step_line%22%2C%20%22func_name%22%3A%20%22%3Cmodule%3E%22%2C%20%22globals%22%3A%20%7B%7D%2C%20%22ordered_globals%22%3A%20%5B%5D%2C%20%22stack_to_render%22%3A%20%5B%5D%2C%20%22heap%22%3A%20%7B%7D%2C%20%22stdout%22%3A%20%22%22%7D%2C%20%7B%22line%22%3A%2014%2C%20%22event%22%3A%20%22step_line%22%2C%20%22func_name%22%3A%20%22%3Cmodule%3E%22%2C%20%22globals%22%3A%20%7B%22binaire%22%3A%20%5B%22REF%22%2C%201%5D%7D%2C%20%22ordered_globals%22%3A%20%5B%22binaire%22%5D%2C%20%22stack_to_render%22%3A%20%5B%5D%2C%20%22heap%22%3A%20%7B%221%22%3A%20%5B%22FUNCTION%22%2C%20%22binaire%28n%29%22%2C%20null%5D%7D%2C%20%22stdout%22%3A%20%22%22%7D%2C%20%7B%22line%22%3A%201%2C%20%22event%22%3A%20%22call%22%2C%20%22func_name%22%3A%20%22binaire%22%2C%20%22globals%22%3A%20%7B%22binaire%22%3A%20%5B%22REF%22%2C%201%5D%7D%2C%20%22ordered_globals%22%3A%20%5B%22binaire%22%5D%2C%20%22stack_to_render%22%3A%20%5B%7B%22func_name%22%3A%20%22binaire%22%2C%20%22is_parent%22%3A%20false%2C%20%22frame_id%22%3A%201%2C%20%22parent_frame_id_list%22%3A%20%5B%5D%2C%20%22encoded_locals%22%3A%20%7B%22n%22%3A%2042%7D%2C%20%22ordered_varnames%22%3A%20%5B%22n%22%5D%2C%20%22is_zombie%22%3A%20false%2C%20%22is_highlighted%22%3A%20true%2C%20%22unique_hash%22%3A%20%22binaire_f1%22%7D%5D%2C%20%22heap%22%3A%20%7B%221%22%3A%20%5B%22FUNCTION%22%2C%20%22binaire%28n%29%22%2C%20null%5D%7D%2C%20%22stdout%22%3A%20%22%22%7D%2C%20%7B%22line%22%3A%202%2C%20%22event%22%3A%20%22step_line%22%2C%20%22func_name%22%3A%20%22binaire%22%2C%20%22globals%22%3A%20%7B%22binaire%22%3A%20%5B%22REF%22%2C%201%5D%7D%2C%20%22ordered_globals%22%3A%20%5B%22binaire%22%5D%2C%20%22stack_to_render%22%3A%20%5B%7B%22func_name%22%3A%20%22bi ...

# %% [markdown]
# **Ex5** En remarquant que le dernier bit peut être obtenu avec la fonction elle-même,
#
# écrire l'**arbre** des appels successifs avec le programme ci-dessous.

# %%
import tutor

def binaire(n):
    if n==0:
        return '0'
    elif n==1:
        return '1'
    else:
        return binaire(n//2)+binaire(n%2)
    
binaire(42)

tutor.tutor()
# Out:
# <iframe id="basthon-pythontutor-iframe-1" style="width: 100%; height: 400px;" frameborder="0" src="data:text/html;charset=utf-8,%3C%21DOCTYPE%20html%3E%0A%3Chtml%3E%0A%20%20%3Chead%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//notebook.basthon.fr/assets/0.60.2/python3/modules/extern/pytutor-main.min.css%22/%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//notebook.basthon.fr/assets/0.60.2/python3/modules/extern/pytutor-main.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20let%20sent_height%3B%0A%20%20%20%20%20%20%24%28document%29.ready%28function%28%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20//%20managing%20iframe%20resize%0A%20%20%20%20%20%20%20%20%20%20const%20send%20%3D%20%28%29%20%3D%3E%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20const%20new_height%20%3D%20document.body.offsetHeight%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20if%20%28sent_height%20%3D%3D%3D%20new_height%29%20return%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20sent_height%20%3D%20new_height%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20window.parent.postMessage%28%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20type%3A%20%22pytutor-iframe-resize%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20target%3A%20%22basthon-pythontutor-iframe-1%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20sent_height%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%2C%20%27%2A%27%29%3B%0A%20%20%20%20%20%20%20%20%20%20%7D%3B%0A%20%20%20%20%20%20%20%20%20%20const%20o%20%3D%20new%20ResizeObserver%28send%29%3B%0A%20%20%20%20%20%20%20%20%20%20o.observe%28document.body%29%3B%0A%0A%20%20%20%20%20%20%20%20%20%20const%20t%20%3D%20%7B%22code%22%3A%20%22def%20binaire%28n%29%3A%5Cn%20%20%20%20if%20n%3D%3D0%3A%5Cn%20%20%20%20%20%20%20%20return%20%270%27%5Cn%20%20%20%20elif%20n%3D%3D1%3A%5Cn%20%20%20%20%20%20%20%20return%20%271%27%5Cn%20%20%20%20else%3A%5Cn%20%20%20%20%20%20%20%20return%20binaire%28n//2%29%2Bbinaire%28n%252%29%5Cn%20%20%20%20%5Cnbinaire%2842%29%22%2C%20%22trace%22%3A%20%5B%7B%22line%22%3A%201%2C%20%22event%22%3A%20%22step_line%22%2C%20%22func_name%22%3A%20%22%3Cmodule%3E%22%2C%20%22globals%22%3A%20%7B%7D%2C%20%22ordered_globals%22%3A%20%5B%5D%2C%20%22stack_to_render%22%3A%20%5B%5D%2C%20%22heap%22%3A%20%7B%7D%2C%20%22stdout%22%3A%20%22%22%7D%2C%20%7B%22line%22%3A%209%2C%20%22event%22%3A%20%22step_line%22%2C%20%22func_name%22%3A%20%22%3Cmodule%3E%22%2C%20%22globals%22%3A%20%7B%22binaire%22%3A%20%5B%22REF%22%2C%201%5D%7D%2C%20%22ordered_globals%22%3A%20%5B%22binaire%22%5D%2C%20%22stack_to_render%22%3A%20%5B%5D%2C%20%22heap%22%3A%20%7B%221%22%3A%20%5B%22FUNCTION%22%2C%20%22binaire%28n%29%22%2C%20null%5D%7D%2C%20%22stdout%22%3A%20%22%22%7D%2C%20%7B%22line%22%3A%201%2C%20%22event%22%3A%20%22call%22%2C%20%22func_name%22%3A%20%22binaire%22%2C%20%22globals%22%3A%20%7B%22binaire%22%3A%20%5B%22REF%22%2C%201%5D%7D%2C%20%22ordered_globals%22%3A%20%5B%22binaire%22%5D%2C%20%22stack_to_render%22%3A%20%5B%7B%22func_name%22%3A%20%22binaire%22%2C%20%22is_parent%22%3A%20false%2C%20%22frame_id%22%3A%201%2C%20%22parent_frame_id_list%22%3A%20%5B%5D%2C%20%22encoded_locals%22%3A%20%7B%22n%22%3A%2042%7D%2C%20%22ordered_varnames%22%3A%20%5B%22n%22%5D%2C%20%22is_zombie%22%3A%20false%2C%20%22is_highlighted%22%3A%20true%2C%20%22unique_hash%22%3A%20%22binaire_f1%22%7D%5D%2C%20%22heap%22%3A%20%7B%221%22%3A%20%5B%22FUNCTION%22%2C%20%22binaire%28n%29%22%2C%20null%5D%7D%2C%20%22stdout%22%3A%20%22%22%7D%2C%20%7B%22line%22%3A%202%2C%20%22event%22%3A%20%22step_line%22%2C%20%22func_name%22%3A%20%22binaire%22%2C%20%22globals%22%3A%20%7B%22binaire%22%3A%20%5B%22REF%22%2C%201%5D%7D%2C%20%22ordered_globals%22%3A%20%5B%22binaire%22%5D%2C%20%22stack_to_render%22%3A%20%5B%7B%22func_name%22%3A%20%22binaire%22%2C%20%22is_parent%22%3A%20false%2C%20%22frame_id%22%3A%201%2C%20%22parent_frame_id_list%22%3A%20%5B%5D%2C%20%22encoded_locals%22%3A%20%7B%22n%22%3A%2042%7D%2C%20%22ordered_varnames%22%3A%20%5B%22n%22%5D%2C%2 ...

# %% [markdown]
# Le site <a href="https://www.recursionvisualizer.com/?function_definition=def%20binaire%28n%29%3A%0A%20%20%20%20if%20n%3D%3D0%3A%0A%20%20%20%20%20%20%20%20return%20'0'%0A%20%20%20%20elif%20n%3D%3D1%3A%0A%20%20%20%20%20%20%20%20return%20'1'%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20%20%20return%20binaire%28n%2F%2F2%29%2Bbinaire%28n%252%29%0A&function_call=binaire%2842%29">recursionvisualizer.com</a> permet de construire des piles d'appels aussi bien que des arbres d'appels.

# %% [markdown]
# **Ex6** La suite de Fibonacci 0, 1, 1, 2, 3, 5, 8, 13, 21, ... est obtenue en calculant chaque terme comme somme des deux termes précédents.
#
# Mathématiquement cela s'écrit $u_0=0$, $u_1=1$ et $u_{n+2}=u_{n+1}+u_n$ pour tout $n \in \mathbb{N}$,
#
# informatiquement cela se traduit par la fonction récursive ci-dessous.
#
# 1. Dessiner l'arbre des appels récursifs avec comme appel initial `fibo(5)` (on peut utiliser <a href="recursionvisualizer.com">recursionvizualiser.com</a>).
# 2. Combien d'appels à la fonction sont alors utilisés ?
# 3. Dérécursifier la fonction.

# %%
def fibo(n):
    if n<2:
        return n
    else:
        return fibo(n-1)+fibo(n-2)

# %%
def fibo_iter(n):
    for i in range :
        
    return n
fibo_iter(5)

# %% [markdown]
# **Ex7** Le tri rapide (`quicksort`) est un tri récursif qui consiste à choisir une valeur **pivot**, puis à trier récursivement et séparément d'une part la liste des éléments inférieurs au pivot, d'autre part la liste des éléments inférieurs au pivot.
#
# Dessiner l'arbre des appels récursifs pour le cas d'usage proposé.

# %%
def quicksort(l):
    if len(l)<2:
        return l
    else:
        pivot=l[0]
        infs=[x for x in l[1:] if x<pivot]
        sups=[x for x in l[1:] if x>=pivot]
        return quicksort(infs)+[pivot]+quicksort(sups)

quicksort([80,76,14,50,35,22,29,56,44,85])

# %% [markdown]
# On peut comparer avec cet autre appel.

# %%
quicksort([50,76,29,80,35,22,14,56,44,85])

# %% [markdown]
# **Ex8** Passons aux choses sérieuses : **énumération**
#
# La fonction `parties(l,k)` renvoie la lsite de toutes les parties de la liste `l` contenant `k` éléments.
#
# Dérécursifier cette fonction.

# %%
def parties(l,k):
    if l==[] or k==0:
        return []
    if k==1:
        return [[u] for u in l]
    return [[l[0]]+u for u in parties(l[1:],k-1)]+parties(l[1:],k)

parties([1,2,3,4,5,6,7],3)
